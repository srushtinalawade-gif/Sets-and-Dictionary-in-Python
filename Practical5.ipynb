# %% [markdown]
# <a href="https://colab.research.google.com/github/srushtinalawade-gif/Sets-and-Dictionary-in-Python/blob/main/Practical5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # To Study Sets and Dictionary in Python
# ### Name- Srushti J. Nalawade
# ### PRN- 25070123157
# ### Branch- ENTC A1

# %%
# Creation of Set
stationary={"pencil","pen","scale"}
print(stationary)
# Out:
# {'pen', 'pencil', 'scale'}

# %%
# Duplicates not allowed
stationary={"pencil","pen","scale","pen"}
print(stationary)
# Out:
# {'pen', 'pencil', 'scale'}

# %%
# True and 1 are considered same
stationary={"pencil","pen","scale",True, 1, False, 0}
print(stationary)
# Out:
# {False, True, 'pen', 'pencil', 'scale'}

# %%
# Set wiht strings, integers and boolean values
thisset={'anvi',38,False,18.8}
print(thisset)
# Out:
# {False, 'anvi', 18.8, 38}

# %%
# Searching in Set
stationary={"pencil","pen","scale"}
print('pencil' in stationary)
print('eraser' in stationary)
# Out:
# True
# False

# %%
# Items in sets are not replaceable, but items can be added and deleted from them
stationary={"pencil","pen","scale","pen"}
stationary.add('eraser')
stationary.remove('pen')

print(stationary)
# Out:
# {'eraser', 'pencil', 'scale'}

# %%
# Set operations
a={1,2,6,4}
b={5,4,7,6}

print('Union:', a|b)
print('Intersection:',a & b)
print('Difference:',a-b)
print('Symmetric Difference:', a^b)
# Out:
# Union: {1, 2, 4, 5, 6, 7}
# Intersection: {4, 6}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 5, 7}

# %%
# Frozen Set
f_s=frozenset({"pencil","pen","scale"})
print(f_s)
print(type(f_s))
# Out:
# frozenset({'pen', 'pencil', 'scale'})
# <class 'frozenset'>

# %%
# Adding and removing is not allowed in frozen set
f_s=frozenset({"pencil","pen","scale"})
f_s.add('eraser')
f_s.remove('pen')

print(f_s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2662793777.py in <cell line: 0>()
#       1 # Adding and removing is not allowed in frozen set
#       2 f_s=frozenset({"pencil","pen","scale"})
# ----> 3 f_s.add('eraser')
#       4 f_s.remove('pen')
#       5
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# Problem 1
student_names=['Aadi','Arddra','Apoorba','Srushti','Aadi','Anvi','Prek','Prek','Apoorba','Ansh','Ansh S']
unique_student=set(student_names)
print('The List of Students who have registered:')
print(unique_student)
# Out:
# The List of Students who have registered:
# {'Anvi', 'Arddra', 'Srushti', 'Prek', 'Ansh', 'Aadi', 'Apoorba', 'Ansh S'}

# %%
# Problem 2
anvi={'AMT','EDP','PES','EG','Cybersecurity'}
arya={'DEVC','EI','ERA','IAI','Cybersecurity'}
srushti={'LA','EEEE','ECSF','FMS','Cybersecurity'}

print('The common subject is',anvi&arya&srushti)
# Out:
# The common subject is {'Cybersecurity'}

# %%
# Problem 3
cricket={'Aadi','Ansh','Arya','Apoorba','Rohan','Arddra'}
football={'Rohan','Arya','Srushti','Arddra','Prek'}
print('Both Clubs:',cricket & football)
print('Only one clubs:',cricket^football)
# Out:
# Both Clubs: {'Rohan', 'Arya', 'Arddra'}
# Only one clubs: {'Ansh', 'Aadi', 'Apoorba', 'Srushti', 'Prek'}

# %%
# Problem 4
all_students={'aadi','ansh','ansh s', 'apoorba','srushti','ananya','aditi'}
present_students={'aadi','ansh','apoorba'}
print('absent students are',all_students-present_students)
# Out:
# absent students are {'aditi', 'ananya', 'srushti', 'ansh s'}

# %%
# Problem 5
courses=['TS6001','FT0097','TC6007','EG003']
print('Total course',courses)
actual_courses=set(courses)
actual_courses.remove('EG003')
print('Actual Courses',actual_courses)
# Out:
# Total course ['TS6001', 'FT0097', 'TC6007', 'EG003']
# Actual Courses {'TC6007', 'FT0097', 'TS6001'}

# %% [markdown]
# # Dictionary

# %%
# Creation of Dictionary
thisdict={
    'company':'apple',
    'product':'iphone',
    'year': 2025
}
print(thisdict)
# Out:
# {'company': 'apple', 'product': 'iphone', 'year': 2025}

# %%
# Dictionary takes latest value given to key. It doesnt allow duplicates
thisdict={
    'company':'apple',
    'product':'iphone',
    'year': 2023,
    'year':2025
}
print(thisdict)
# Out:
# {'company': 'apple', 'product': 'iphone', 'year': 2025}

# %%
# Length of key-value pair
len(thisdict)
# Out:
# 3

# %%
# Changing/ Adding key:value in dictionary
product={
    'company':'apple',
    'product':'iphone',
    'year': 2025
}
product['colour']='lavender'
x=product.values()
y=product.keys()
print(x)
print(y)
# Out:
# dict_values(['apple', 'iphone', 2025, 'lavender'])
# dict_keys(['company', 'product', 'year', 'colour'])

# %%
customer={
    'name':'Neil',
    'product':'Powerbank',
    'date':'30 jan'
}
print('Customer Name:',customer['name'])
# Out:
# Customer Name: Ayush

# %%
# Adding and Updating Elements
customer['product2']='Headphones'
customer['name']='Prisha'
print(customer)
# Out:
# {'name': 'Prisha', 'product': 'Charger', 'date': '30 jan', 'product2': 'Headphones'}

# %%
# Removing Elements
customer.pop('date')
print('updated details:',customer)
# Out:
# updated details: {'name': 'Prisha', 'product': 'Charger', 'product2': 'Headphones'}

# %%
# Problem 1
products={
    'milk':25,
    'cereal':80,
    'bread':35,
    'cheese':30,
    'nutella':285,
    'chips':30
}
print('Original Price:',products)

products['nutella']=150
print('Updated Price',products)
# Out:
# Original Price: {'milk': 25, 'cereal': 80, 'bread': 35, 'cheese': 30, 'nutella': 285, 'chips': 30}
# Updated Price {'milk': 25, 'cereal': 80, 'bread': 35, 'cheese': 30, 'nutella': 150, 'chips': 30}

# %%
# Problem 2
marks={
    'Aayushi':78,
    'Seerat':89,
    'Avani':76,
    'Kimaya':80
}
name=input('Enter student name:')
print(marks.get(name,'Student not found')) #works like if-else
# Out:
# Enter student name:Avani
# 76

# %%
# Problem 3
logins={
    'emp1':'emp001',
    'emp2':'emp002',
    'emp3':'emp003',
    'emp4':'emp004'
}
user_id=input('Enter user id:')
if  user_id in logins.keys():
  password=input('Enter password:')
  if password==logins[user_id]:
    print('Access Granted')
else:
  print('User not found')
# Out:
# Enter user id:emp2
# Enter password:emp002
# Access Granted

# %%
# Problem 4
maths={
    'asmi':10,
    'Mano':9.5,
    'srushti':9,
    'Arshiya':8,
    'Pushkar':4
}
topper=max(maths, key=maths.get)
print('The class topper is',topper)
# Out:
# The class topper is asmi
